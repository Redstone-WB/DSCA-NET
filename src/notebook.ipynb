# %%
import pandas as pd
import pickle as pkl

# %% [markdown]
# ### DATA EDA

# %%
patient = pd.read_csv('../data/mimic-iii-clinical-database-1.4/PATIENTS.csv')
admission = pd.read_csv('../data/mimic-iii-clinical-database-1.4/ADMISSIONS.csv')

# %%
print(patient.shape)
print(admission.shape)
# Out:
# (46520, 8)
# (58976, 19)

# %%
patient.head(3)
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0

# %%
admission.head(3)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE      RELIGION MARITAL_STATUS  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN  UNOBTAINABLE        MARRIED
# 1           HOME HEALTH CARE  Medicare      NaN      CATHOLIC        MARRIED
# 2           HOME HEALTH CARE  Medicare     ENGL      CATHOLIC        MARRIED
#
#   ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1     WHITE                  NaN                  NaN
# 2     WHITE                  NaN                  NaN
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1

# %%
patients['DOB'].max()
# Out:
# '2201-07-24 00:00:00'

# %%
patients['DOB'].min()
# Out:
# '1800-07-02 00:00:00'

# %%
pres = pd.read_csv('../data/mimic-iii-clinical-database-1.4/PRESCRIPTIONS.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8h/c4nc3b111l56r38yfxstwq740000gq/T/ipykernel_77852/3889748029.py in <module>
# ----> 1 pres = pd.read_csv('../data/mimic-iii-clinical-database-1.4/PRESCRIPTIONS.csv')
#
# NameError: name 'pd' is not defined

# %%
pres.head(3)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  469061711.0
# 1          Warfarin             WARF5  006562   56017275.0
# 2               NaN        HEPAPREMIX  006522  338055002.0
#
#             PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# 0             1mg Capsule           2           mg             2
# 1              5mg Tablet           5           mg             1
# 2  25,000 unit Premix Bag      25,000         UNIT             1
#
#   FORM_UNIT_DISP ROUTE
# 0            CAP    PO
# 1            TAB    PO
# 2            BAG    IV

# %%
## 매우 큰 테이블
# chart = pd.read_csv('../data/mimic-iii-clinical-database-1.4/CHARTEVENTS.csv')
dtt = pd.read_csv('../data/mimic-iii-clinical-database-1.4/DATETIMEEVENTS.csv')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dtt.head(3)
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0     711        7657  121183.0    297945.0    3411  2172-03-14 11:00:00
# 1     712        7657  121183.0    297945.0    3411  2172-03-14 13:00:00
# 2     713        7657  121183.0    297945.0    3411  2172-03-14 15:00:00
#
#              STORETIME   CGID VALUE VALUEUOM  WARNING  ERROR  RESULTSTATUS  \
# 0  2172-03-14 11:52:00  16446   NaN     Date      NaN    NaN           NaN
# 1  2172-03-14 12:36:00  16446   NaN     Date      NaN    NaN           NaN
# 2  2172-03-14 15:10:00  14957   NaN     Date      NaN    NaN           NaN
#
#     STOPPED
# 0  NotStopd
# 1  NotStopd
# 2  NotStopd

# %%
items = pd.read_csv('../data/mimic-iii-clinical-database-1.4/D_ITEMS.csv')

# %%
items[items['ITEMID'] == 3411]
# Out:
#       ROW_ID  ITEMID              LABEL ABBREVIATION DBSOURCE         LINKSTO  \
# 1831    1012    3411  Equip Change [MM]          NaN  carevue  datetimeevents
#
#      CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 1831      NaN      NaN        NaN        NaN

# %%
items[items['LABEL'].isin(['PH'])]
# Out:
#       ROW_ID  ITEMID LABEL ABBREVIATION DBSOURCE      LINKSTO CATEGORY  \
# 2938    3122    1673    PH          NaN  carevue  chartevents      NaN
#
#      UNITNAME PARAM_TYPE  CONCEPTID
# 2938      NaN        NaN        NaN

# %%
items[items['ITEMID'] ==220224]
# Out:
#        ROW_ID  ITEMID                 LABEL    ABBREVIATION    DBSOURCE  \
# 11526   12740  220224  Arterial O2 pressure  PO2 (Arterial)  metavision
#
#            LINKSTO CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 11526  chartevents     Labs     mmHg    Numeric        NaN

# %%
items[(items['CATEGORY'] == 'Labs') & ~(items['UNITNAME'] == 'None')]
# Out:
#        ROW_ID  ITEMID                   LABEL            ABBREVIATION  \
# 9924    14846  227516      PO2 (Mixed Venous)      PO2 (Mixed Venous)
# 10541   14117  225674    Mixed Venous O2% Sat    Mixed Venous O2% Sat
# 11189   15021  227686  Central Venous O2% Sat  Central Venous O2% Sat
# 11526   12740  220224    Arterial O2 pressure          PO2 (Arterial)
# 11527   12741  220227  Arterial O2 Saturation                    SaO2
# 11528   12742  220228              Hemoglobin              Hemoglobin
# 11529   12743  220235   Arterial CO2 Pressure         PCO2 (Arterial)
# 11644   14344  226062     Venous CO2 Pressure           PCO2 (Venous)
# 11645   14345  226063      Venous O2 Pressure            PO2 (Venous)
# 11872   14388  226482     Blood Clot Outdates     Blood Clot Outdates
#
#          DBSOURCE         LINKSTO CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 9924   metavision     chartevents     Labs     mmHg    Numeric        NaN
# 10541  metavision     chartevents     Labs        %    Numeric        NaN
# 11189  metavision     chartevents     Labs        %    Numeric        NaN
# 11526  metavision     chartevents     Labs     mmHg    Numeric        NaN
# 11527  metavision     chartevents     Labs        %    Numeric        NaN
# 11528  metavision     chartevents     Labs     g/dl    Numeric        NaN
# 11529  metavision     chartevents     Labs     mmHg    Numeric        NaN
# 11644  metavision     chartevents     Labs     mmHg    Numeric        NaN
# 11645  metavision     chartevents     Labs     mmHg    Numeric        NaN
# 11872  metavision  datetimeevents     Labs      NaN  Date time        NaN

# %%
items[items['LABEL'].str.contains('urine', na=False)].head(30)
# Out:
#       ROW_ID  ITEMID                 LABEL ABBREVIATION DBSOURCE  \
# 10      1162     941         urine culture          NaN  carevue
# 30      1182    1011      urine osmolarity          NaN  carevue
# 1232    1361    1352              urine pH          NaN  carevue
# 2459    1913    5810         urine calcium          NaN  carevue
# 2460    1914    5811      urine creatinine          NaN  carevue
# 2540    1994    5898              urine na          NaN  carevue
# 2766    2950    1495              urine ph          NaN  carevue
# 3677    2600    6204         urine for CMV          NaN  carevue
# 3699    2622    6226          urine for AA          NaN  carevue
# 4129    4129    6304            urine cath          NaN  carevue
# 4416    5706   40534           urine flush          NaN  carevue
# 5095    4358    6754              urine PH          NaN  carevue
# 5252    6503   41857       urine out in er          NaN  carevue
# 5472    7631   42463        cath lab urine          NaN  carevue
# 5654    7157   43173         urinecc/kg/hr          NaN  carevue
# 6024    6423   42119    urine output-angio          NaN  carevue
# 6163    8948   43897          urine in er.          NaN  carevue
# 6175    8970   43931       Floor urine out          NaN  carevue
# 6191    9005   43966     real urine output          NaN  carevue
# 6253    9095   44103          ER urine out          NaN  carevue
# 6271    9118   44132   Procedure urine out          NaN  carevue
# 6314    9199   44237        E.R. urine out          NaN  carevue
# 6342    9254   44313             f10 urine          NaN  carevue
# 6412    7279   43348       urine output/kg          NaN  carevue
# 6414    7284   43355            urine/k/hr          NaN  carevue
# 6418    7294   43365    urine output/kg/hr          NaN  carevue
# 6422    7301   43372     24hr urine output          NaN  carevue
# 6423    7302   43373        urine cc/kg/hr          NaN  carevue
# 6426    7309   43380  urine outpt cc/kg/hr          NaN  carevue
# 6447    7369   43462                 urine          NaN  carevue
#
#            LINKSTO          CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 10     chartevents               NaN      NaN        NaN        NaN
# 30     chartevents               NaN      NaN        NaN        NaN
# 1232   chartevents               NaN      NaN        NaN        NaN
# 2459   chartevents               NaN      NaN        NaN        NaN
# 2460   chartevents               NaN      NaN        NaN        NaN
# 2540   chartevents               NaN      NaN        NaN        NaN
# 2766   chartevents               NaN      NaN        NaN        NaN
# 3677   chartevents               NaN      NaN        NaN        NaN
# 3699   chartevents               NaN      NaN        NaN        NaN
# 4129   chartevents               NaN      NaN        NaN        NaN
# 4416  outputevents  Free Form Intake      NaN        NaN        NaN
# 5095   chartevents               NaN      NaN        NaN        NaN
# 5252  outputevents               NaN      NaN        NaN        NaN
# 5472  outputevents               NaN      NaN        NaN        NaN
# 5654  outputevents               NaN      NaN        NaN        NaN
# 6024  outputevents               NaN      NaN        NaN        NaN
# 6163  outputevents               NaN      NaN        NaN        NaN
# 6175  outputevents               NaN      NaN        NaN        NaN
# 6191  outputevents               NaN      NaN        NaN        NaN
# 6253  outputevents               NaN      NaN        NaN        NaN
# 6271  outputevents               NaN      NaN        NaN        NaN
# 6314  outputevents               NaN      NaN        NaN        NaN
# 6342  outputevents               NaN      NaN        NaN        NaN
# 6412  outputevents               NaN      NaN        NaN        NaN
# 6414  outputevents               NaN      NaN        NaN        NaN
# 6418  outputevents               NaN      NaN        NaN        NaN
# 6422  outputevents               NaN      NaN        NaN        NaN
# 6423  outputevents               NaN      NaN        NaN        NaN
# 6426  outputevents               NaN      NaN        NaN        NaN
# 6447  outputevents               NaN      NaN        NaN        NaN

# %%
items[items['LABEL'].str.contains('heart', na=False)]
# Out:
#       ROW_ID  ITEMID              LABEL ABBREVIATION DBSOURCE      LINKSTO  \
# 2610    2064    5972    fetal heartrate          NaN  carevue  chartevents
# 3417    3786    2781  fetal heart sound          NaN  carevue  chartevents
#
#      CATEGORY UNITNAME PARAM_TYPE  CONCEPTID
# 2610      NaN      NaN        NaN        NaN
# 3417      NaN      NaN        NaN        NaN

# %% [markdown]
# ### Preprocess
#
# - pid : [pid1, pid2, ...]
# - vid : [[pid1-vid1, pid1-vid2], [pid2-vid1, pid2-vid2, pid2-vid3]]
# - x_dem : demographic
#   - [[demo1, demo2, demo3, ... demon], [demo1, demo2, ..., demon]]
# - x_per : examination
#   - [[[v1-pers], [v2-pers]], [[v1-pers], [v2-pers], [v3-pers]], ... ]
# - x_d : prescription
#   - [[[v1-pres], [v2-pres]], [[v1-pres], [v2-pres], [v3-pres]], ...]

# %%
### Extract TOP400 DRUGS

pres.head(3)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  469061711.0
# 1          Warfarin             WARF5  006562   56017275.0
# 2               NaN        HEPAPREMIX  006522  338055002.0
#
#             PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# 0             1mg Capsule           2           mg             2
# 1              5mg Tablet           5           mg             1
# 2  25,000 unit Premix Bag      25,000         UNIT             1
#
#   FORM_UNIT_DISP ROUTE
# 0            CAP    PO
# 1            TAB    PO
# 2            BAG    IV

# %%
pres['FORMULARY_DRUG_CD'].drop_duplicates().shape
# Out:
# (3268,)

# %%
top400 = pres['FORMULARY_DRUG_CD'].value_counts()[:400].index

# %%
top400
# Out:
# Index(['FURO40I', 'NACLFLUSH', 'INSULIN', 'D5W250', 'NS1000', 'NS500',
#        'MAG2PM', 'VANC1F', 'VANCOBASE', 'METO25',
#        ...
#        'MIRT15', 'MORP15', 'ALPR25', 'AMP2I', 'NEOR100', 'GABA100', 'CLON1',
#        'VECU10I', 'MULT5L', 'OXYC10'],
#       dtype='object', length=400)

# %%
patient['SUBJECT_ID'].drop_duplicates().shape
# Out:
# (46520,)

# %%
admission['SUBJECT_ID'].drop_duplicates().shape
# Out:
# (46520,)
